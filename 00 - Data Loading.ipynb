# %% [markdown]
# Get some data to play with

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.keys()
# Out:
# dict_keys(['DESCR', 'images', 'data', 'target_names', 'target'])

# %%
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
print(digits.images[0])
# Out:
# [[  0.   0.   5.  13.   9.   1.   0.   0.]
#  [  0.   0.  13.  15.  10.  15.   5.   0.]
#  [  0.   3.  15.   2.   0.  11.   8.   0.]
#  [  0.   4.  12.   0.   0.   8.   8.   0.]
#  [  0.   5.   8.   0.   0.   9.   8.   0.]
#  [  0.   4.  11.   0.   1.  12.   7.   0.]
#  [  0.   2.  14.   5.  10.  12.   0.   0.]
#  [  0.   0.   6.  13.  10.   0.   0.   0.]]

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

plt.matshow(digits.images[1796], cmap=plt.cm.Greys)
# Out:
# <img src="data:image/png;base64,...">

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.target.shape
# Out:
# (1797,)

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %% [markdown]
# **Data is always a numpy array (or sparse matrix) of shape (n_samples, n_features)**

# %% [markdown]
# Split the data to get going

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(digits.data,
                                                    digits.target)

# %% [markdown]
# # Exercises
#
# Load the iris dataset from the ``sklearn.datasets`` module using the ``load_iris`` function.
# The function returns a dictionary-like object that has the same attributes as ``digits``.
#
# What is the number of classes, features and data points in this dataset?
# Use a scatterplot to visualize the dataset.
#
# You can look at ``DESCR`` attribute to learn more about the dataset.

# %%
# %load solutions/load_iris.py
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['DESCR', 'data', 'feature_names', 'target_names', 'target'])

# %%
iris.feature_names
iris.target_names
iris.data.shape
# Out:
# (150, 4)

# %%
# %matplotlib notebook
images = []
for idx in range(4):
    images.append(plt.figure(idx+1))
    plt.scatter(x=range(len(iris.data)), y=[i[idx] for i in iris.data])
    images[idx].show()
#plt.scatter(iris.data)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
# %load solutions/load_iris.py
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.cross_validation import train_test_split

iris = load_iris()
X, y = iris.data, iris.target

print("Dataset size: %d  number of features: %d  number of classes: %d"
      % (X.shape[0], X.shape[1], len(np.unique(y))))

X_train, X_test, y_train, y_test = train_test_split(X, y)

plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)3
plt.figure()
plt.scatter(X_train[:, 2], X_train[:, 3], c=y_train)
# Out:
# Dataset size: 150  number of features: 4  number of classes: 3
# <img src="data:image/png;base64,...">

# %%
# %load solutions/load_iris.py
